# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv('./data/train.csv')
test = pd.read_csv('./data/test.csv')
train
# Out:
#                       timestamp    back_x    back_y    back_z   thigh_x  \
# 0       2000-01-01 00:00:00.000 -0.956569 -0.098830  0.080135 -0.960096
# 1       2000-01-01 00:00:00.020 -0.998093 -0.111525  0.078602 -1.020245
# 2       2000-01-01 00:00:00.040 -0.948218 -0.091371  0.083376 -0.970062
# 3       2000-01-01 00:00:00.060 -0.995374 -0.078641  0.099155 -1.011861
# 4       2000-01-01 00:00:00.080 -0.956965 -0.078572  0.088926 -0.999605
# ...                         ...       ...       ...       ...       ...
# 270683  2000-01-01 01:33:21.460 -0.937662  0.046846 -0.325718  0.295120
# 270684  2000-01-01 01:33:21.480 -0.937337  0.046903 -0.332703  0.295699
# 270685  2000-01-01 01:33:21.500 -0.937663  0.046848 -0.340252  0.295122
# 270686  2000-01-01 01:33:21.520 -0.937336  0.046901 -0.337360  0.295697
# 270687  2000-01-01 01:33:21.540 -0.937665  0.046850 -0.345779  0.295124
#
#          thigh_y   thigh_z  label
# 0      -0.162203 -0.019368      6
# 1      -0.092208 -0.045086      6
# 2      -0.115447 -0.058316      6
# 3      -0.133171 -0.024171      6
# 4      -0.024058 -0.077175      6
# ...          ...       ...    ...
# 270683  0.266235  0.920978      7
# 270684  0.258065  0.925238      7
# 270685  0.247369  0.922798      7
# 270686  0.250210  0.924713      7
# 270687  0.248847  0.922986      7
#
# [270688 rows x 8 columns]

# %%
test
# Out:
#                      timestamp    back_x    back_y    back_z   thigh_x  \
# 0      2000-01-01 01:33:21.560 -0.937335  0.046899 -0.342502  0.295695
# 1      2000-01-01 01:33:21.580 -0.937666  0.046852 -0.344900  0.295126
# 2      2000-01-01 01:33:21.600 -0.937333  0.046897 -0.336490  0.295694
# 3      2000-01-01 01:33:21.620 -0.937668  0.046854 -0.340287  0.295127
# 4      2000-01-01 01:33:21.640 -0.937332  0.046895 -0.330291  0.295692
# ...                        ...       ...       ...       ...       ...
# 90224  2000-01-01 02:09:26.880 -0.990168 -0.060075  0.081295 -0.986077
# 90225  2000-01-01 02:09:26.900 -0.949873 -0.063681  0.074504 -0.961862
# 90226  2000-01-01 02:09:26.920 -1.010094 -0.060867  0.082230 -1.019280
# 90227  2000-01-01 02:09:26.940 -0.958566 -0.075775  0.073181 -0.985680
# 90228  2000-01-01 02:09:26.960 -1.011049 -0.076941  0.086553 -1.008323
#
#         thigh_y   thigh_z
# 0      0.264578  0.924721
# 1      0.265042  0.922686
# 2      0.265239  0.925745
# 3      0.265118  0.932006
# 4      0.265059  0.920916
# ...         ...       ...
# 90224 -0.033986  0.022038
# 90225 -0.096602 -0.000282
# 90226 -0.079514  0.028906
# 90227 -0.114626 -0.010128
# 90228 -0.086885  0.042776
#
# [90229 rows x 7 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270688 entries, 0 to 270687
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  270688 non-null  object
#  1   back_x     270688 non-null  float64
#  2   back_y     270688 non-null  float64
#  3   back_z     270688 non-null  float64
#  4   thigh_x    270688 non-null  float64
#  5   thigh_y    270688 non-null  float64
#  6   thigh_z    270688 non-null  float64
#  7   label      270688 non-null  int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 16.5+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90229 entries, 0 to 90228
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  90229 non-null  object
#  1   back_x     90229 non-null  float64
#  2   back_y     90229 non-null  float64
#  3   back_z     90229 non-null  float64
#  4   thigh_x    90229 non-null  float64
#  5   thigh_y    90229 non-null  float64
#  6   thigh_z    90229 non-null  float64
# dtypes: float64(6), object(1)
# memory usage: 4.8+ MB

# %%
for df in (train , test): 
    df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce')
    df.sort_values('timestamp', inplace=True)
    df.reset_index(drop=True, inplace=True)

# %%
train
# Out:
#                      timestamp    back_x    back_y    back_z   thigh_x  \
# 0      2000-01-01 00:00:00.000 -0.956569 -0.098830  0.080135 -0.960096
# 1      2000-01-01 00:00:00.020 -0.998093 -0.111525  0.078602 -1.020245
# 2      2000-01-01 00:00:00.040 -0.948218 -0.091371  0.083376 -0.970062
# 3      2000-01-01 00:00:00.060 -0.995374 -0.078641  0.099155 -1.011861
# 4      2000-01-01 00:00:00.080 -0.956965 -0.078572  0.088926 -0.999605
# ...                        ...       ...       ...       ...       ...
# 270683 2000-01-01 01:33:21.460 -0.937662  0.046846 -0.325718  0.295120
# 270684 2000-01-01 01:33:21.480 -0.937337  0.046903 -0.332703  0.295699
# 270685 2000-01-01 01:33:21.500 -0.937663  0.046848 -0.340252  0.295122
# 270686 2000-01-01 01:33:21.520 -0.937336  0.046901 -0.337360  0.295697
# 270687 2000-01-01 01:33:21.540 -0.937665  0.046850 -0.345779  0.295124
#
#          thigh_y   thigh_z  label
# 0      -0.162203 -0.019368      6
# 1      -0.092208 -0.045086      6
# 2      -0.115447 -0.058316      6
# 3      -0.133171 -0.024171      6
# 4      -0.024058 -0.077175      6
# ...          ...       ...    ...
# 270683  0.266235  0.920978      7
# 270684  0.258065  0.925238      7
# 270685  0.247369  0.922798      7
# 270686  0.250210  0.924713      7
# 270687  0.248847  0.922986      7
#
# [270688 rows x 8 columns]

# %%
test
# Out:
#                     timestamp    back_x    back_y    back_z   thigh_x  \
# 0     2000-01-01 01:33:21.560 -0.937335  0.046899 -0.342502  0.295695
# 1     2000-01-01 01:33:21.580 -0.937666  0.046852 -0.344900  0.295126
# 2     2000-01-01 01:33:21.600 -0.937333  0.046897 -0.336490  0.295694
# 3     2000-01-01 01:33:21.620 -0.937668  0.046854 -0.340287  0.295127
# 4     2000-01-01 01:33:21.640 -0.937332  0.046895 -0.330291  0.295692
# ...                       ...       ...       ...       ...       ...
# 90224 2000-01-01 02:09:26.880 -0.990168 -0.060075  0.081295 -0.986077
# 90225 2000-01-01 02:09:26.900 -0.949873 -0.063681  0.074504 -0.961862
# 90226 2000-01-01 02:09:26.920 -1.010094 -0.060867  0.082230 -1.019280
# 90227 2000-01-01 02:09:26.940 -0.958566 -0.075775  0.073181 -0.985680
# 90228 2000-01-01 02:09:26.960 -1.011049 -0.076941  0.086553 -1.008323
#
#         thigh_y   thigh_z
# 0      0.264578  0.924721
# 1      0.265042  0.922686
# 2      0.265239  0.925745
# 3      0.265118  0.932006
# 4      0.265059  0.920916
# ...         ...       ...
# 90224 -0.033986  0.022038
# 90225 -0.096602 -0.000282
# 90226 -0.079514  0.028906
# 90227 -0.114626 -0.010128
# 90228 -0.086885  0.042776
#
# [90229 rows x 7 columns]

# %%
print("rows -> train:", len(train), "| test:", len(test))
print("nulls(train):", train.isnull().sum().to_dict())
print("nulls(test):",  test.isnull().sum().to_dict())
print("time monotonic ->", train['timestamp'].is_monotonic_increasing, test['timestamp'].is_monotonic_increasing)
# Out:
# rows -> train: 270688 | test: 90229
# nulls(train): {'timestamp': 0, 'back_x': 0, 'back_y': 0, 'back_z': 0, 'thigh_x': 0, 'thigh_y': 0, 'thigh_z': 0, 'label': 0}
# nulls(test): {'timestamp': 0, 'back_x': 0, 'back_y': 0, 'back_z': 0, 'thigh_x': 0, 'thigh_y': 0, 'thigh_z': 0}
# time monotonic -> True True

# %%
dt = train['timestamp'].diff().dropna().dt.total_seconds()
fs = 1/dt[dt>0].median()
print("median delta time (s):", dt[dt>0].median(), " ~ fs (Hz):", fs)
# Out:
# median delta time (s): 0.02  ~ fs (Hz): 50.0

# %%
if 'label' in train.columns:
    print("label counts:\n", train['label'].value_counts().sort_index())
# Out:
# label counts:
#  label
# 1     20074
# 2      1806
# 3     13540
# 4      3040
# 5      2350
# 6     49568
# 7    176258
# 8      4052
# Name: count, dtype: int64
